# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /drive/MyDrive/Colab Notebooks

# %%
# !git clone https://github.com/cpraveen/chebpy
# Out:
# Cloning into 'chebpy'...
# remote: Enumerating objects: 344, done.
# remote: Counting objects: 100% (133/133), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 344 (delta 71), reused 86 (delta 30), pack-reused 211 (from 1)
# Receiving objects: 100% (344/344), 6.83 MiB | 11.46 MiB/s, done.
# Resolving deltas: 100% (207/207), done.

# %%
# %cd chebpy
# !ls
# Out:
# ader_dg			fenics	   foglizzo.ipynb			Untitled0.ipynb
# Colab_animations.ipynb	firedrake  Julia_Colab_Notebook_Template.ipynb	WuhanVirusIndiaDeaths.ipynb
